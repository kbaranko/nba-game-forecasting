# %%
import pandas as pd 
import nba_api as nba 
import requests

# %%
from nba_api.stats.static import teams
from nba_api.stats.endpoints import leaguegamefinder
from nba_api.stats.endpoints import scoreboard
from nba_api.stats.endpoints import boxscoreadvancedv2

# %%
#helper function to create list of dates in a given range, which will be used for each NBA season studied
def get_regular_season_dates(begin, end):
    datelist = pd.date_range(start=begin, end=end).tolist()
    return datelist

# %%
date = '2018-10-31'

# %%
day_game_data = scoreboard.Scoreboard(day_offset=0 , game_date=date, league_id='00')
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# ~/anaconda3/envs/sports-ml/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                     # Otherwise it looks like a bug in the code.
# --> 421                     six.raise_from(e, None)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~/anaconda3/envs/sports-ml/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/anaconda3/envs/sports-ml/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     415                 try:
# --> 416                     httplib_response = conn.getresponse()
#     417                 except BaseException as e:
#
# ~/anaconda3/envs/sports-ml/lib/python3.7/http/client.py in getresponse(self)
#    1343             try:
# -> 1344                 response.begin()
#    1345             except ConnectionError:
#
# ~/anaconda3/envs/sports-ml/lib/python3.7/http/client.py in begin(self)
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#
# ~/anaconda3/envs/sports-ml/lib/python3.7/http/client.py in _read_status(self)
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#
# ~/anaconda3/envs/sports-ml/lib/python3.7/socket.py in readinto(self, b)
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#
# ~/anaconda3/envs/sports-ml/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#
# ~/anaconda3/envs/sports-ml/lib/python3.7/ssl.py in read(self, len, buffer)
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#
# timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# ~/anaconda3/envs/sports-ml/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~/anaconda3/envs/sports-ml/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     719             retries = retries.increment(
# --> 720                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     721             )
#
# ~/anaconda3/envs/sports-ml/lib/python3.7/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     399             if read is False or not self._is_method_retryable(method):
# --> 400                 raise six.reraise(type(error), error, _stacktrace)
#     401             elif read is not None:
#
# ~/anaconda3/envs/sports-ml/lib/python3.7/site-packages/urllib3/packages/six.py in reraise(tp, value, tb)
#     734                 raise value.with_traceback(tb)
# --> 735             raise value
#     736         finally:
#
# ~/anaconda3/envs/sports-ml/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#
# ~/anaconda3/envs/sports-ml/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
# --> 423             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     424             raise
#
# ~/anaconda3/envs/sports-ml/lib/python3.7/site-packages/urllib3/connectionpool.py in _raise_timeout(self, err, url, timeout_value)
#     330             raise ReadTimeoutError(
# --> 331                 self, url, "Read timed out. (read timeout=%s)" % timeout_value
#     332             )
#
# ReadTimeoutError: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# <ipython-input-7-3236c0f71cb9> in <module>
# ----> 1 day_game_data = scoreboard.Scoreboard(day_offset=0 , game_date=date, league_id='00')
#
# ~/anaconda3/envs/sports-ml/lib/python3.7/site-packages/nba_api/stats/endpoints/scoreboard.py in __init__(self, day_offset, game_date, league_id, proxy, headers, timeout, get_request)
#      32         }
#      33         if get_request:
# ---> 34             self.get_request()
#      35
#      36     def get_request(self):
#
# ~/anaconda3/envs/sports-ml/lib/python3.7/site-packages/nba_api/stats/endpoints/scoreboard.py in get_request(self)
#      40             proxy=self.proxy,
#      41             headers=self.headers,
# ---> 42             timeout=self.timeout,
#      43         )
#      44         self.load_response()
#
# ~/anaconda3/envs/sports-ml/lib/python3.7/site-packages/nba_api/library/http.py in send_api_request(self, endpoint, parameters, referer, proxy, headers, timeout, raise_exception_on_error)
#     121
#     122         if not contents:
# --> 123             response = requests.get(url=base_url, params=parameters, headers=request_headers, proxies=proxies, timeout=timeout)
#     124             url = response.url
#     125             status_code = response.status_code
#
# ~/anaconda3/envs/sports-ml/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/anaconda3/envs/sports-ml/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/anaconda3/envs/sports-ml/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/anaconda3/envs/sports-ml/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/envs/sports-ml/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     527                 raise SSLError(e, request=request)
#     528             elif isinstance(e, ReadTimeoutError):
# --> 529                 raise ReadTimeout(e, request=request)
#     530             else:
#     531                 raise
#
# ReadTimeout: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)

# %%
#input begin and end date, return dataframe with all game results and features 
def get_nba_data(begin, end):
    dates = get_regular_season_dates(begin, end)
    yearly_sample = []
    headers = {
    'Host': 'stats.nba.com',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:61.0) Gecko/20100101 Firefox/61.0',
    'Accept': 'application/json, text/plain, */*',
    'Accept-Language': 'en-US,en;q=0.5',
    'Referer': 'https://stats.nba.com/',
    'Accept-Encoding': 'gzip, deflate, br',
    'Connection': 'keep-alive',
    }
    for date in dates:
        day_game_data = scoreboard.Scoreboard(day_offset=0 , game_date=date, league_id='00', headers=headers)
        games = day_game_data.get_data_frames()
        summary = games[0]
        game_ids = summary['GAME_ID'].tolist()
        daily_sample = []
        for game_id in game_ids:
            game = boxscoreadvancedv2.BoxScoreAdvancedV2(game_id=game_id)
            game = game.get_data_frames()
            outcome = game[1]
            outcome = outcome.stack().to_frame().T
            outcome.columns = ['{}_{}'.format(*c) for c in outcome.columns]
            daily_sample.append(outcome)
        yearly_sample.extend(daily_sample)
    df = pd.concat(yearly_sample)
    df = df.drop('1_GAME_ID', 1)
    df = df.rename({'0_GAME_ID': 'GAME_ID'}, axis=1)
    df = df.set_index('GAME_ID')
    return df

# %%
test = get_nba_data('2018-10-31', '2018-11-10')
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# ~/anaconda3/envs/sports-ml/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                     # Otherwise it looks like a bug in the code.
# --> 421                     six.raise_from(e, None)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~/anaconda3/envs/sports-ml/lib/python3.7/site-packages/urllib3/packages/six.py in raise_from(value, from_value)
#
# ~/anaconda3/envs/sports-ml/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     415                 try:
# --> 416                     httplib_response = conn.getresponse()
#     417                 except BaseException as e:
#
# ~/anaconda3/envs/sports-ml/lib/python3.7/http/client.py in getresponse(self)
#    1343             try:
# -> 1344                 response.begin()
#    1345             except ConnectionError:
#
# ~/anaconda3/envs/sports-ml/lib/python3.7/http/client.py in begin(self)
#     305         while True:
# --> 306             version, status, reason = self._read_status()
#     307             if status != CONTINUE:
#
# ~/anaconda3/envs/sports-ml/lib/python3.7/http/client.py in _read_status(self)
#     266     def _read_status(self):
# --> 267         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     268         if len(line) > _MAXLINE:
#
# ~/anaconda3/envs/sports-ml/lib/python3.7/socket.py in readinto(self, b)
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#
# ~/anaconda3/envs/sports-ml/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#
# ~/anaconda3/envs/sports-ml/lib/python3.7/ssl.py in read(self, len, buffer)
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#
# timeout: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeoutError                          Traceback (most recent call last)
# ~/anaconda3/envs/sports-ml/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~/anaconda3/envs/sports-ml/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     719             retries = retries.increment(
# --> 720                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     721             )
#
# ~/anaconda3/envs/sports-ml/lib/python3.7/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     399             if read is False or not self._is_method_retryable(method):
# --> 400                 raise six.reraise(type(error), error, _stacktrace)
#     401             elif read is not None:
#
# ~/anaconda3/envs/sports-ml/lib/python3.7/site-packages/urllib3/packages/six.py in reraise(tp, value, tb)
#     734                 raise value.with_traceback(tb)
# --> 735             raise value
#     736         finally:
#
# ~/anaconda3/envs/sports-ml/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     671                 headers=headers,
# --> 672                 chunked=chunked,
#     673             )
#
# ~/anaconda3/envs/sports-ml/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     422         except (SocketTimeout, BaseSSLError, SocketError) as e:
# --> 423             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     424             raise
#
# ~/anaconda3/envs/sports-ml/lib/python3.7/site-packages/urllib3/connectionpool.py in _raise_timeout(self, err, url, timeout_value)
#     330             raise ReadTimeoutError(
# --> 331                 self, url, "Read timed out. (read timeout=%s)" % timeout_value
#     332             )
#
# ReadTimeoutError: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# <ipython-input-5-59106e8bb164> in <module>
# ----> 1 test = get_nba_data('2018-10-31', '2018-11-10')
#
# <ipython-input-4-58202da10676> in get_nba_data(begin, end)
#      13     }
#      14     for date in dates:
# ---> 15         day_game_data = scoreboard.Scoreboard(day_offset=0 , game_date=date, league_id='00', headers=headers)
#      16         games = day_game_data.get_data_frames()
#      17         summary = games[0]
#
# ~/anaconda3/envs/sports-ml/lib/python3.7/site-packages/nba_api/stats/endpoints/scoreboard.py in __init__(self, day_offset, game_date, league_id, proxy, headers, timeout, get_request)
#      32         }
#      33         if get_request:
# ---> 34             self.get_request()
#      35
#      36     def get_request(self):
#
# ~/anaconda3/envs/sports-ml/lib/python3.7/site-packages/nba_api/stats/endpoints/scoreboard.py in get_request(self)
#      40             proxy=self.proxy,
#      41             headers=self.headers,
# ---> 42             timeout=self.timeout,
#      43         )
#      44         self.load_response()
#
# ~/anaconda3/envs/sports-ml/lib/python3.7/site-packages/nba_api/library/http.py in send_api_request(self, endpoint, parameters, referer, proxy, headers, timeout, raise_exception_on_error)
#     121
#     122         if not contents:
# --> 123             response = requests.get(url=base_url, params=parameters, headers=request_headers, proxies=proxies, timeout=timeout)
#     124             url = response.url
#     125             status_code = response.status_code
#
# ~/anaconda3/envs/sports-ml/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/anaconda3/envs/sports-ml/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/anaconda3/envs/sports-ml/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/anaconda3/envs/sports-ml/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/envs/sports-ml/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     527                 raise SSLError(e, request=request)
#     528             elif isinstance(e, ReadTimeoutError):
# --> 529                 raise ReadTimeout(e, request=request)
#     530             else:
#     531                 raise
#
# ReadTimeout: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30)

# %%
test.head()

# %%
test = test.reset_index()

# %%
test.head()
# Out:
#       GAME_ID   0_TEAM_ID 0_TEAM_NAME 0_TEAM_ABBREVIATION  0_TEAM_CITY  \
# 0  0021800104  1610612765     Pistons                 DET      Detroit
# 1  0021800105  1610612752      Knicks                 NYK     New York
# 2  0021800106  1610612743     Nuggets                 DEN       Denver
# 3  0021800107  1610612762        Jazz                 UTA         Utah
# 4  0021800108  1610612740    Pelicans                 NOP  New Orleans
#
#     0_MIN 0_E_OFF_RATING 0_OFF_RATING 0_E_DEF_RATING 0_DEF_RATING  ...  \
# 0  265:00          105.2        107.2            107        108.1  ...
# 1  240:00          103.5        103.1          112.1        111.5  ...
# 2  265:00            102        106.9            103        104.9  ...
# 3  240:00            120        120.2          121.3        123.1  ...
# 4  240:00          112.2        114.2          122.2        122.4  ...
#
#   1_TM_TOV_PCT 1_EFG_PCT 1_TS_PCT 1_USG_PCT 1_E_USG_PCT 1_E_PACE  1_PACE  \
# 0         14.4     0.485    0.525         1       0.198   102.05  100.53
# 1         15.6     0.578    0.591         1       0.199    96.52      97
# 2         13.7     0.511    0.535         1       0.197    95.02   91.92
# 3         15.4     0.651    0.663         1       0.197   104.88     104
# 4         15.9     0.618    0.641         1         0.2   107.54   106.5
#
#   1_PACE_PER40 1_POSS  1_PIE
# 0        83.77    111  0.499
# 1        80.83     96  0.583
# 2         76.6    102   0.47
# 3        86.67    104  0.521
# 4        88.75    107   0.58
#
# [5 rows x 57 columns]

# %%
#function to create the time series features for each team 
def create_features(df):
    away_team_ids = df['0_TEAM_ID'].to_list()
    away_team_ids = set(away_team_ids)
    home_team_ids = df['1_TEAM_ID'].to_list()
    home_team_ids = set(home_team_ids)
    for i, j in iterrows():

# %%
test[1].columns
# Out:
# Index(['0_GAME_ID', '0_TEAM_ID', '0_TEAM_NAME', '0_TEAM_ABBREVIATION',
#        '0_TEAM_CITY', '0_MIN', '0_E_OFF_RATING', '0_OFF_RATING',
#        '0_E_DEF_RATING', '0_DEF_RATING', '0_E_NET_RATING', '0_NET_RATING',
#        '0_AST_PCT', '0_AST_TOV', '0_AST_RATIO', '0_OREB_PCT', '0_DREB_PCT',
#        '0_REB_PCT', '0_E_TM_TOV_PCT', '0_TM_TOV_PCT', '0_EFG_PCT', '0_TS_PCT',
#        '0_USG_PCT', '0_E_USG_PCT', '0_E_PACE', '0_PACE', '0_PACE_PER40',
#        '0_POSS', '0_PIE', '1_GAME_ID', '1_TEAM_ID', '1_TEAM_NAME',
#        '1_TEAM_ABBREVIATION', '1_TEAM_CITY', '1_MIN', '1_E_OFF_RATING',
#        '1_OFF_RATING', '1_E_DEF_RATING', '1_DEF_RATING', '1_E_NET_RATING',
#        '1_NET_RATING', '1_AST_PCT', '1_AST_TOV', '1_AST_RATIO', '1_OREB_PCT',
#        '1_DREB_PCT', '1_REB_PCT', '1_E_TM_TOV_PCT', '1_TM_TOV_PCT',
#        '1_EFG_PCT', '1_TS_PCT', '1_USG_PCT', '1_E_USG_PCT', '1_E_PACE',
#        '1_PACE', '1_PACE_PER40', '1_POSS', '1_PIE'],
#       dtype='object')

# %%
dates = get_regular_season_dates('2018-10-31', '2019-3-28')

# %%
day_game_data = scoreboard.Scoreboard(day_offset=0 , game_date='2019-03-27' , league_id='00')

# %%
day_game_data

# %%
games = day_game_data.get_data_frames()

# %%
len(games)
# Out:
# 7

# %%
summary = games[0]

# %%
outcome = games[1]

# %%
summary['outcome'] = outcome.iloc[0,21] - outcome.iloc[1,21]

# %%
summary
# Out:
#          GAME_DATE_EST  GAME_SEQUENCE     GAME_ID  GAME_STATUS_ID  \
# 0  2019-03-27T00:00:00              1  0021801117               3
# 1  2019-03-27T00:00:00              2  0021801118               3
# 2  2019-03-27T00:00:00              3  0021801119               3
# 3  2019-03-27T00:00:00              4  0021801120               3
# 4  2019-03-27T00:00:00              5  0021801121               3
#
#   GAME_STATUS_TEXT         GAMECODE  HOME_TEAM_ID  VISITOR_TEAM_ID SEASON  \
# 0            Final  20190327/PORCHI    1610612741       1610612757   2018
# 1            Final  20190327/GSWMEM    1610612763       1610612744   2018
# 2            Final  20190327/INDOKC    1610612760       1610612754   2018
# 3            Final  20190327/WASPHX    1610612756       1610612764   2018
# 4            Final  20190327/LALUTA    1610612762       1610612747   2018
#
#    LIVE_PERIOD LIVE_PC_TIME NATL_TV_BROADCASTER_ABBREVIATION  \
# 0            4                                          None
# 1            4                                          None
# 2            4                                          ESPN
# 3            4                                          None
# 4            4                                          ESPN
#
#   LIVE_PERIOD_TIME_BCAST  WH_STATUS  outcome
# 0            Q4       -           1       20
# 1            Q4       -           1       20
# 2        Q4       - ESPN          1       20
# 3            Q4       -           1       20
# 4        Q4       - ESPN          1       20

# %%
outcome.columns
# Out:
# Index(['GAME_DATE_EST', 'GAME_SEQUENCE', 'GAME_ID', 'TEAM_ID',
#        'TEAM_ABBREVIATION', 'TEAM_CITY_NAME', 'TEAM_WINS_LOSSES', 'PTS_QTR1',
#        'PTS_QTR2', 'PTS_QTR3', 'PTS_QTR4', 'PTS_OT1', 'PTS_OT2', 'PTS_OT3',
#        'PTS_OT4', 'PTS_OT5', 'PTS_OT6', 'PTS_OT7', 'PTS_OT8', 'PTS_OT9',
#        'PTS_OT10', 'PTS', 'FG_PCT', 'FT_PCT', 'FG3_PCT', 'AST', 'REB', 'TOV'],
#       dtype='object')

# %%
outcome
# Out:
#          GAME_DATE_EST  GAME_SEQUENCE     GAME_ID     TEAM_ID  \
# 0  2019-03-27T00:00:00              1  0021801117  1610612757
# 1  2019-03-27T00:00:00              1  0021801117  1610612741
# 2  2019-03-27T00:00:00              2  0021801118  1610612744
# 3  2019-03-27T00:00:00              2  0021801118  1610612763
# 4  2019-03-27T00:00:00              3  0021801119  1610612754
# 5  2019-03-27T00:00:00              3  0021801119  1610612760
# 6  2019-03-27T00:00:00              4  0021801120  1610612764
# 7  2019-03-27T00:00:00              4  0021801120  1610612756
# 8  2019-03-27T00:00:00              5  0021801121  1610612747
# 9  2019-03-27T00:00:00              5  0021801121  1610612762
#
#   TEAM_ABBREVIATION TEAM_CITY_NAME TEAM_WINS_LOSSES  PTS_QTR1  PTS_QTR2  \
# 0               POR       Portland            47-27        27        32
# 1               CHI        Chicago            21-55        14        27
# 2               GSW   Golden State            51-23        31        35
# 3               MEM        Memphis            30-45        37        23
# 4               IND        Indiana            45-30        27        27
# 5               OKC  Oklahoma City            44-31        29        16
# 6               WAS     Washington            31-45        27        32
# 7               PHX        Phoenix            17-59        30        29
# 8               LAL    Los Angeles            33-42        25        28
# 9               UTA           Utah            45-30        32        28
#
#    PTS_QTR3  ...  PTS_OT8  PTS_OT9  PTS_OT10  PTS  FG_PCT  FT_PCT  FG3_PCT  \
# 0        28  ...        0        0         0  118   0.518   0.840    0.344
# 1        24  ...        0        0         0   98   0.429   0.789    0.217
# 2        23  ...        0        0         0  118   0.536   0.867    0.484
# 3        24  ...        0        0         0  103   0.390   0.714    0.323
# 4        15  ...        0        0         0   99   0.435   0.545    0.419
# 5        31  ...        0        0         0  107   0.446   0.632    0.361
# 6        30  ...        0        0         0  124   0.478   0.674    0.360
# 7        31  ...        0        0         0  121   0.494   0.808    0.378
# 8        18  ...        0        0         0  100   0.381   0.708    0.333
# 9        27  ...        0        0         0  115   0.494   0.639    0.313
#
#    AST  REB  TOV
# 0   30   45    8
# 1   22   44    8
# 2   30   46   14
# 3   22   51    9
# 4   26   45   11
# 5   29   44    6
# 6   18   52   10
# 7   22   48   15
# 8   21   40    4
# 9   33   54   11
#
# [10 rows x 28 columns]

# %%
def isolate

# %%
game_ids =

# %%
gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable=)

# %%
game = boxscoreadvancedv2.BoxScoreAdvancedV2(game_id='0021801117')

# %%
game = game.get_data_frames()

# %%
len(game)
# Out:
# 2

# %%
game[0].columns
# Out:
# Index(['GAME_ID', 'TEAM_ID', 'TEAM_ABBREVIATION', 'TEAM_CITY', 'PLAYER_ID',
#        'PLAYER_NAME', 'START_POSITION', 'COMMENT', 'MIN', 'E_OFF_RATING',
#        'OFF_RATING', 'E_DEF_RATING', 'DEF_RATING', 'E_NET_RATING',
#        'NET_RATING', 'AST_PCT', 'AST_TOV', 'AST_RATIO', 'OREB_PCT', 'DREB_PCT',
#        'REB_PCT', 'TM_TOV_PCT', 'EFG_PCT', 'TS_PCT', 'USG_PCT', 'E_USG_PCT',
#        'E_PACE', 'PACE', 'PACE_PER40', 'POSS', 'PIE'],
#       dtype='object')

# %%
game[1].columns
# Out:
# Index(['GAME_ID', 'TEAM_ID', 'TEAM_NAME', 'TEAM_ABBREVIATION', 'TEAM_CITY',
#        'MIN', 'E_OFF_RATING', 'OFF_RATING', 'E_DEF_RATING', 'DEF_RATING',
#        'E_NET_RATING', 'NET_RATING', 'AST_PCT', 'AST_TOV', 'AST_RATIO',
#        'OREB_PCT', 'DREB_PCT', 'REB_PCT', 'E_TM_TOV_PCT', 'TM_TOV_PCT',
#        'EFG_PCT', 'TS_PCT', 'USG_PCT', 'E_USG_PCT', 'E_PACE', 'PACE',
#        'PACE_PER40', 'POSS', 'PIE'],
#       dtype='object')

# %%
o = game[1]

# %%
o['NET_RATING']
# Out:
# 0    20.6
# 1   -20.6
# Name: NET_RATING, dtype: float64

# %%
df = game[1]

# %%
df = df.stack().to_frame().T
df.columns = ['{}_{}'.format(*c) for c in df.columns]

# %%
df
# Out:
#     0_GAME_ID   0_TEAM_ID    0_TEAM_NAME 0_TEAM_ABBREVIATION 0_TEAM_CITY  \
# 0  0021801117  1610612757  Trail Blazers                 POR    Portland
#
#     0_MIN 0_E_OFF_RATING 0_OFF_RATING 0_E_DEF_RATING 0_DEF_RATING  ...  \
# 0  240:00          126.9        128.3            105        107.7  ...
#
#   1_TM_TOV_PCT 1_EFG_PCT 1_TS_PCT 1_USG_PCT 1_E_USG_PCT 1_E_PACE 1_PACE  \
# 0           11     0.456    0.493         1       0.194    93.18   91.5
#
#   1_PACE_PER40 1_POSS  1_PIE
# 0        76.25     91  0.373
#
# [1 rows x 58 columns]

# %%
df['outcome']

# %%
df.columns
# Out:
# Index(['0_GAME_ID', '0_TEAM_ID', '0_TEAM_NAME', '0_TEAM_ABBREVIATION',
#        '0_TEAM_CITY', '0_MIN', '0_E_OFF_RATING', '0_OFF_RATING',
#        '0_E_DEF_RATING', '0_DEF_RATING', '0_E_NET_RATING', '0_NET_RATING',
#        '0_AST_PCT', '0_AST_TOV', '0_AST_RATIO', '0_OREB_PCT', '0_DREB_PCT',
#        '0_REB_PCT', '0_E_TM_TOV_PCT', '0_TM_TOV_PCT', '0_EFG_PCT', '0_TS_PCT',
#        '0_USG_PCT', '0_E_USG_PCT', '0_E_PACE', '0_PACE', '0_PACE_PER40',
#        '0_POSS', '0_PIE', '1_GAME_ID', '1_TEAM_ID', '1_TEAM_NAME',
#        '1_TEAM_ABBREVIATION', '1_TEAM_CITY', '1_MIN', '1_E_OFF_RATING',
#        '1_OFF_RATING', '1_E_DEF_RATING', '1_DEF_RATING', '1_E_NET_RATING',
#        '1_NET_RATING', '1_AST_PCT', '1_AST_TOV', '1_AST_RATIO', '1_OREB_PCT',
#        '1_DREB_PCT', '1_REB_PCT', '1_E_TM_TOV_PCT', '1_TM_TOV_PCT',
#        '1_EFG_PCT', '1_TS_PCT', '1_USG_PCT', '1_E_USG_PCT', '1_E_PACE',
#        '1_PACE', '1_PACE_PER40', '1_POSS', '1_PIE'],
#       dtype='object')

# %%
def create_winner(summary):
    summary['winner'] = 0
    if

# %%
outcome
# Out:
#          GAME_DATE_EST  GAME_SEQUENCE     GAME_ID     TEAM_ID  \
# 0  2019-03-27T00:00:00              1  0021801117  1610612757
# 1  2019-03-27T00:00:00              1  0021801117  1610612741
# 2  2019-03-27T00:00:00              2  0021801118  1610612744
# 3  2019-03-27T00:00:00              2  0021801118  1610612763
# 4  2019-03-27T00:00:00              3  0021801119  1610612754
# 5  2019-03-27T00:00:00              3  0021801119  1610612760
# 6  2019-03-27T00:00:00              4  0021801120  1610612764
# 7  2019-03-27T00:00:00              4  0021801120  1610612756
# 8  2019-03-27T00:00:00              5  0021801121  1610612747
# 9  2019-03-27T00:00:00              5  0021801121  1610612762
#
#   TEAM_ABBREVIATION TEAM_CITY_NAME TEAM_WINS_LOSSES  PTS_QTR1  PTS_QTR2  \
# 0               POR       Portland            47-27        27        32
# 1               CHI        Chicago            21-55        14        27
# 2               GSW   Golden State            51-23        31        35
# 3               MEM        Memphis            30-45        37        23
# 4               IND        Indiana            45-30        27        27
# 5               OKC  Oklahoma City            44-31        29        16
# 6               WAS     Washington            31-45        27        32
# 7               PHX        Phoenix            17-59        30        29
# 8               LAL    Los Angeles            33-42        25        28
# 9               UTA           Utah            45-30        32        28
#
#    PTS_QTR3  ...  PTS_OT8  PTS_OT9  PTS_OT10  PTS  FG_PCT  FT_PCT  FG3_PCT  \
# 0        28  ...        0        0         0  118   0.518   0.840    0.344
# 1        24  ...        0        0         0   98   0.429   0.789    0.217
# 2        23  ...        0        0         0  118   0.536   0.867    0.484
# 3        24  ...        0        0         0  103   0.390   0.714    0.323
# 4        15  ...        0        0         0   99   0.435   0.545    0.419
# 5        31  ...        0        0         0  107   0.446   0.632    0.361
# 6        30  ...        0        0         0  124   0.478   0.674    0.360
# 7        31  ...        0        0         0  121   0.494   0.808    0.378
# 8        18  ...        0        0         0  100   0.381   0.708    0.333
# 9        27  ...        0        0         0  115   0.494   0.639    0.313
#
#    AST  REB  TOV
# 0   30   45    8
# 1   22   44    8
# 2   30   46   14
# 3   22   51    9
# 4   26   45   11
# 5   29   44    6
# 6   18   52   10
# 7   22   48   15
# 8   21   40    4
# 9   33   54   11
#
# [10 rows x 28 columns]

# %%
summary
# Out:
#          GAME_DATE_EST  GAME_SEQUENCE     GAME_ID  GAME_STATUS_ID  \
# 0  2019-03-27T00:00:00              1  0021801117               3
# 1  2019-03-27T00:00:00              2  0021801118               3
# 2  2019-03-27T00:00:00              3  0021801119               3
# 3  2019-03-27T00:00:00              4  0021801120               3
# 4  2019-03-27T00:00:00              5  0021801121               3
#
#   GAME_STATUS_TEXT         GAMECODE  HOME_TEAM_ID  VISITOR_TEAM_ID SEASON  \
# 0            Final  20190327/PORCHI    1610612741       1610612757   2018
# 1            Final  20190327/GSWMEM    1610612763       1610612744   2018
# 2            Final  20190327/INDOKC    1610612760       1610612754   2018
# 3            Final  20190327/WASPHX    1610612756       1610612764   2018
# 4            Final  20190327/LALUTA    1610612762       1610612747   2018
#
#    LIVE_PERIOD LIVE_PC_TIME NATL_TV_BROADCASTER_ABBREVIATION  \
# 0            4                                          None
# 1            4                                          None
# 2            4                                          ESPN
# 3            4                                          None
# 4            4                                          ESPN
#
#   LIVE_PERIOD_TIME_BCAST  WH_STATUS
# 0            Q4       -           1
# 1            Q4       -           1
# 2        Q4       - ESPN          1
# 3            Q4       -           1
# 4        Q4       - ESPN          1

# %%
outcome.columns
# Out:
# Index(['GAME_DATE_EST', 'GAME_SEQUENCE', 'GAME_ID', 'TEAM_ID',
#        'TEAM_ABBREVIATION', 'TEAM_CITY_NAME', 'TEAM_WINS_LOSSES', 'PTS_QTR1',
#        'PTS_QTR2', 'PTS_QTR3', 'PTS_QTR4', 'PTS_OT1', 'PTS_OT2', 'PTS_OT3',
#        'PTS_OT4', 'PTS_OT5', 'PTS_OT6', 'PTS_OT7', 'PTS_OT8', 'PTS_OT9',
#        'PTS_OT10', 'PTS', 'FG_PCT', 'FT_PCT', 'FG3_PCT', 'AST', 'REB', 'TOV'],
#       dtype='object')
